# %%
import sys

"""

The Elves each reach into their pack and pull out a tiny plant. The plants rely on important nutrients from the ash, so they can't be planted too close together.

There isn't enough time to let the Elves figure out where to plant the seedlings themselves; you quickly scan the grove (your puzzle input) and note their positions.

For example:

....#..
..###.#
#...#.#
.#...##
#.###..
##.#.##
.#..#..

The scan shows Elves # and empty ground .; outside your scan, more empty ground extends a long way in every direction. The scan is oriented so that north is up; orthogonal directions are written N (north), S (south), W (west), and E (east), while diagonal directions are written NE, NW, SE, SW.

The process consists of some number of rounds during which Elves alternate between considering where to move and actually moving.

During the first half of each round, each Elf considers the eight positions adjacent to themself. If no other Elves are in one of those eight positions, the Elf does not do anything during this round. Otherwise, the Elf looks in each of four directions in the following order and proposes moving one step in the first valid direction:

If there is no Elf in the N, NE, or NW adjacent positions, the Elf proposes moving north one step.
If there is no Elf in the S, SE, or SW adjacent positions, the Elf proposes moving south one step.
If there is no Elf in the W, NW, or SW adjacent positions, the Elf proposes moving west one step.
If there is no Elf in the E, NE, or SE adjacent positions, the Elf proposes moving east one step.

After each Elf has had a chance to propose a move, the second half of the round can begin. Simultaneously, each Elf moves to their proposed destination tile if they were the only Elf to propose moving to that position. If two or more Elves propose moving to the same position, none of those Elves move.

Finally, at the end of the round, the first direction the Elves considered is moved to the end of the list of directions. For example, during the second round, the Elves would try proposing a move to the south first, then west, then east, then north. On the third round, the Elves would first consider west, then east, then north, then south.

---
Round sequence:
1. All Elves consider their 8 adjacent positions.
1.a. If they are solo, they end their round
1.b. If they are not solo, they propose a move to the first valid direction, in the following order:
     N if no Elf in N, NE, NW
     S if no Elf in S, SE, SW
     W if no Elf in W, NW, SW
     E if no Elf in E, NE, SE

2. All Elves move to their proposed destination tile if they were the only Elf to propose moving to that position.

3. The order of the decision is rotated by one, so that the first direction the Elves considered is moved to the end of the list of directions.
---

Rounds continue until no Elves are able to move (they have no elf in any of the 8 adjacent positions).
"""

def parse_file_to_grid(filename):
    with open(filename, 'r') as f:
        grid = [list(line.strip()) for line in f.readlines()]
    return grid

def print_grid(grid):
    for row in grid:
        print(''.join(row))

# %%
def get_elf_positions_from_grid(grid):
    elf_positions = []
    for row_idx, row in enumerate(grid):
        for col_idx, col in enumerate(row):
            if col == '#':
                elf_positions.append((row_idx, col_idx))
    return elf_positions

def grid_for_elf_positions(elf_positions):
    max_row = max(elf_positions, key=lambda x: x[0])[0]
    max_col = max(elf_positions, key=lambda x: x[1])[1]
    grid = [['.' for _ in range(max_col + 1)] for _ in range(max_row + 1)]
    for row, col in elf_positions:
        grid[row][col] = '#'
    return grid

def get_bounding_area(elf_positions):
    min_row = min(elf_positions, key=lambda x: x[0])[0]
    max_row = max(elf_positions, key=lambda x: x[0])[0]
    min_col = min(elf_positions, key=lambda x: x[1])[1]
    max_col = max(elf_positions, key=lambda x: x[1])[1]
    return (max_col - min_col + 1) * (max_row - min_row + 1)

# %%
import enum

class Direction(enum.Enum):
    NW = (-1, -1)
    N = (-1, 0)
    NE = (-1, 1)
    W = (0, -1)
    E = (0, 1)
    SW = (1, -1)
    S = (1, 0)
    SE = (1, 1)

    def offset_from(self, position):
        row, col = position
        return (row + self.value[0], col + self.value[1])

class DecisionOrder:
    NORTHWARD = [Direction.NW, Direction.N, Direction.NE]
    SOUTHWARD = [Direction.SW, Direction.S, Direction.SE]
    WESTWARD = [Direction.NW, Direction.W, Direction.SW]
    EASTWARD = [Direction.NE, Direction.E, Direction.SE]

    ALL_DIRECTIONS = NORTHWARD + SOUTHWARD + WESTWARD + EASTWARD

    INITIAL_ORDER = NORTHWARD, SOUTHWARD, WESTWARD, EASTWARD

    def __init__(self):
        self.directions = DecisionOrder.INITIAL_ORDER

    def rotate(self):
        self.directions = self.directions[1:] + self.directions[:1]

    def __str__(self):
        return str(self.directions)

def get_adjacent_positions(position, directions):
    return [d.offset_from(position) for d in directions]

def elves_in_positions(positions, elf_positions):
    return [p for p in positions if p in elf_positions]

# %%
# Return a dict keyed by current elf position with a value of proposed position
def get_proposed_positions(elf_positions, decision_order):
    proposed_positions = {}
    for elf_position in elf_positions:
        adjacent_positions = get_adjacent_positions(elf_position, decision_order.ALL_DIRECTIONS)
        if not elves_in_positions(adjacent_positions, elf_positions):
            proposed_positions[elf_position] = elf_position
            continue
        for directions in decision_order.directions:
            adjacent_positions = get_adjacent_positions(elf_position, directions)
            if not elves_in_positions(adjacent_positions, elf_positions):
                proposed_positions[elf_position] = directions[1].offset_from(elf_position)
                break
        if elf_position not in proposed_positions:
            proposed_positions[elf_position] = elf_position
    return proposed_positions

# Return a tuple of an array with elf positions updated for non-conflicting moves and the number of moves made
def move_to_proposals(elf_positions, proposals):
    valid_proposals = {k: v for k, v in proposals.items() if list(proposals.values()).count(v) == 1 and k != v}
    return ([valid_proposals.get(p, p) for p in elf_positions], len(valid_proposals))

# %%
decisions = DecisionOrder()
elf_positions = get_elf_positions_from_grid(parse_file_to_grid('./day23-input.txt'))
moves = len(elf_positions)
round = 0

# print("Initial position")
# print_grid(grid_for_elf_positions(elf_positions))
# print()

while moves != 0:
    elf_positions, moves = move_to_proposals(elf_positions, get_proposed_positions(elf_positions, decisions))
    decisions.rotate()
    round += 1

    print("Round {} - {} moves".format(round, moves))
    # print_grid(grid_for_elf_positions(elf_positions))
    # print()

empty_tiles = get_bounding_area(elf_positions) - len(elf_positions)

print("Empty tiles: {}".format(empty_tiles))

# Optimization this time was to just let the computer do its thing for 35 minutes...
# Out:
# Round 1 - 675 moves
# Round 2 - 469 moves
# Round 3 - 396 moves
# Round 4 - 399 moves
# Round 5 - 388 moves
# Round 6 - 402 moves
# Round 7 - 391 moves
# Round 8 - 432 moves
# Round 9 - 429 moves
# Round 10 - 433 moves
# Round 11 - 409 moves
# Round 12 - 444 moves
# Round 13 - 425 moves
# Round 14 - 467 moves
# Round 15 - 456 moves
# Round 16 - 487 moves
# Round 17 - 480 moves
# Round 18 - 505 moves
# Round 19 - 488 moves
# Round 20 - 511 moves
# Round 21 - 484 moves
# Round 22 - 535 moves
# Round 23 - 510 moves
# Round 24 - 535 moves
# Round 25 - 507 moves
# Round 26 - 529 moves
# Round 27 - 520 moves
# Round 28 - 583 moves
# Round 29 - 554 moves
# Round 30 - 586 moves
# Round 31 - 565 moves
# Round 32 - 619 moves
# Round 33 - 569 moves
# Round 34 - 578 moves
# Round 35 - 530 moves
# Round 36 - 600 moves
# Round 37 - 565 moves
# Round 38 - 596 moves
# Round 39 - 580 moves
# Round 40 - 640 moves
# Round 41 - 612 moves
# Round 42 - 646 moves
# Round 43 - 615 moves
# Round 44 - 648 moves
# Round 45 - 608 moves
# Round 46 - 639 moves
# Round 47 - 632 moves
# Round 48 - 658 moves
# Round 49 - 608 moves
# Round 50 - 675 moves
# Round 51 - 634 moves
# Round 52 - 685 moves
# Round 53 - 654 moves
# Round 54 - 720 moves
# Round 55 - 664 moves
# Round 56 - 681 moves
# Round 57 - 661 moves
# Round 58 - 693 moves
# Round 59 - 671 moves
# Round 60 - 704 moves
# Round 61 - 685 moves
# Round 62 - 732 moves
# Round 63 - 687 moves
# Round 64 - 749 moves
# Round 65 - 692 moves
# Round 66 - 733 moves
# Round 67 - 691 moves
# Round 68 - 801 moves
# Round 69 - 764 moves
# Round 70 - 773 moves
# Round 71 - 720 moves
# Round 72 - 771 moves
# Round 73 - 715 moves
# Round 74 - 754 moves
# Round 75 - 696 moves
# Round 76 - 756 moves
# Round 77 - 732 moves
# Round 78 - 782 moves
# Round 79 - 750 moves
# Round 80 - 816 moves
# Round 81 - 775 moves
# Round 82 - 811 moves
# Round 83 - 746 moves
# Round 84 - 821 moves
# Round 85 - 763 moves
# Round 86 - 814 moves
# Round 87 - 766 moves
# Round 88 - 819 moves
# Round 89 - 767 moves
# Round 90 - 821 moves
# Round 91 - 793 moves
# Round 92 - 833 moves
# Round 93 - 809 moves
# Round 94 - 861 moves
# Round 95 - 812 moves
# Round 96 - 846 moves
# Round 97 - 805 moves
# Round 98 - 862 moves
# Round 99 - 820 moves
# Round 100 - 896 moves
# Round 101 - 842 moves
# Round 102 - 873 moves
# Round 103 - 790 moves
# Round 104 - 834 moves
# Round 105 - 819 moves
# Round 106 - 883 moves
# Round 107 - 824 moves
# Round 108 - 900 moves
# Round 109 - 865 moves
# Round 110 - 895 moves
# Round 111 - 831 moves
# Round 112 - 902 moves
# Round 113 - 854 moves
# Round 114 - 915 moves
# Round 115 - 898 moves
# Round 116 - 953 moves
# Round 117 - 926 moves
# Round 118 - 988 moves
# Round 119 - 888 moves
# Round 120 - 911 moves
# Round 121 - 906 moves
# Round 122 - 971 moves
# Round 123 - 919 moves
# Round 124 - 945 moves
# Round 125 - 901 moves
# Round 126 - 939 moves
# Round 127 - 891 moves
# Round 128 - 939 moves
# Round 129 - 865 moves
# Round 130 - 959 moves
# Round 131 - 904 moves
# Round 132 - 956 moves
# Round 133 - 896 moves
# Round 134 - 949 moves
# Round 135 - 903 moves
# Round 136 - 946 moves
# Round 137 - 920 moves
# Round 138 - 954 moves
# Round 139 - 877 moves
# Round 140 - 970 moves
# Round 141 - 910 moves
# Round 142 - 989 moves
# Round 143 - 912 moves
# Round 144 - 972 moves
# Round 145 - 942 moves
# Round 146 - 1041 moves
# Round 147 - 969 moves
# Round 148 - 1001 moves
# Round 149 - 983 moves
# Round 150 - 1066 moves
# Round 151 - 1011 moves
# Round 152 - 1073 moves
# Round 153 - 1006 moves
# Round 154 - 1025 moves
# Round 155 - 971 moves
# Round 156 - 1029 moves
# Round 157 - 982 moves
# Round 158 - 1056 moves
# Round 159 - 994 moves
# Round 160 - 1076 moves
# Round 161 - 987 moves
# Round 162 - 1039 moves
# Round 163 - 1000 moves
# Round 164 - 1066 moves
# Round 165 - 964 moves
# Round 166 - 1024 moves
# Round 167 - 954 moves
# Round 168 - 1018 moves
# Round 169 - 936 moves
# Round 170 - 1053 moves
# Round 171 - 1009 moves
# Round 172 - 1076 moves
# Round 173 - 1020 moves
# Round 174 - 1076 moves
# Round 175 - 1008 moves
# Round 176 - 1057 moves
# Round 177 - 1008 moves
# Round 178 - 1050 moves
# Round 179 - 1005 moves
# Round 180 - 1103 moves
# Round 181 - 1015 moves
# Round 182 - 1118 moves
# Round 183 - 1056 moves
# Round 184 - 1118 moves
# Round 185 - 1072 moves
# Round 186 - 1083 moves
# Round 187 - 1044 moves
# Round 188 - 1092 moves
# Round 189 - 1023 moves
# Round 190 - 1109 moves
# Round 191 - 1022 moves
# Round 192 - 1087 moves
# Round 193 - 1054 moves
# Round 194 - 1112 moves
# Round 195 - 1057 moves
# Round 196 - 1110 moves
# Round 197 - 1032 moves
# Round 198 - 1118 moves
# Round 199 - 1069 moves
# Round 200 - 1124 moves
# Round 201 - 1029 moves
# Round 202 - 1113 moves
# Round 203 - 1085 moves
# Round 204 - 1163 moves
# Round 205 - 1099 moves
# Round 206 - 1136 moves
# Round 207 - 1106 moves
# Round 208 - 1217 moves
# Round 209 - 1118 moves
# Round 210 - 1220 moves
# Round 211 - 1153 moves
# Round 212 - 1190 moves
# Round 213 - 1173 moves
# Round 214 - 1181 moves
# Round 215 - 1105 moves
# Round 216 - 1142 moves
# Round 217 - 1056 moves
# Round 218 - 1125 moves
# Round 219 - 1071 moves
# Round 220 - 1153 moves
# Round 221 - 1093 moves
# Round 222 - 1141 moves
# Round 223 - 1093 moves
# Round 224 - 1188 moves
# Round 225 - 1105 moves
# Round 226 - 1182 moves
# Round 227 - 1075 moves
# Round 228 - 1162 moves
# Round 229 - 1106 moves
# Round 230 - 1169 moves
# Round 231 - 1098 moves
# Round 232 - 1199 moves
# Round 233 - 1119 moves
# Round 234 - 1173 moves
# Round 235 - 1079 moves
# Round 236 - 1190 moves
# Round 237 - 1124 moves
# Round 238 - 1243 moves
# Round 239 - 1183 moves
# Round 240 - 1219 moves
# Round 241 - 1141 moves
# Round 242 - 1230 moves
# Round 243 - 1166 moves
# Round 244 - 1188 moves
# Round 245 - 1115 moves
# Round 246 - 1198 moves
# Round 247 - 1142 moves
# Round 248 - 1226 moves
# Round 249 - 1202 moves
# Round 250 - 1228 moves
# Round 251 - 1151 moves
# Round 252 - 1219 moves
# Round 253 - 1190 moves
# Round 254 - 1236 moves
# Round 255 - 1180 moves
# Round 256 - 1264 moves
# Round 257 - 1206 moves
# Round 258 - 1217 moves
# Round 259 - 1134 moves
# Round 260 - 1255 moves
# Round 261 - 1170 moves
# Round 262 - 1237 moves
# Round 263 - 1162 moves
# Round 264 - 1218 moves
# Round 265 - 1143 moves
# Round 266 - 1271 moves
# Round 267 - 1167 moves
# Round 268 - 1237 moves
# Round 269 - 1152 moves
# Round 270 - 1229 moves
# Round 271 - 1148 moves
# Round 272 - 1215 moves
# Round 273 - 1179 moves
# Round 274 - 1267 moves
# Round 275 - 1200 moves
# Round 276 - 1275 moves
# Round 277 - 1200 moves
# Round 278 - 1300 moves
# Round 279 - 1262 moves
# Round 280 - 1303 moves
# Round 281 - 1247 moves
# Round 282 - 1322 moves
# Round 283 - 1192 moves
# Round 284 - 1244 moves
# Round 285 - 1199 moves
# Round 286 - 1318 moves
# Round 287 - 1226 moves
# Round 288 - 1250 moves
# Round 289 - 1182 moves
# Round 290 - 1261 moves
# Round 291 - 1163 moves
# Round 292 - 1257 moves
# Round 293 - 1190 moves
# Round 294 - 1277 moves
# Round 295 - 1178 moves
# Round 296 - 1248 moves
# Round 297 - 1198 moves
# Round 298 - 1265 moves
# Round 299 - 1196 moves
# Round 300 - 1253 moves
# Round 301 - 1213 moves
# Round 302 - 1282 moves
# Round 303 - 1209 moves
# Round 304 - 1276 moves
# Round 305 - 1203 moves
# Round 306 - 1289 moves
# Round 307 - 1178 moves
# Round 308 - 1263 moves
# Round 309 - 1176 moves
# Round 310 - 1233 moves
# Round 311 - 1206 moves
# Round 312 - 1292 moves
# Round 313 - 1196 moves
# Round 314 - 1275 moves
# Round 315 - 1228 moves
# Round 316 - 1310 moves
# Round 317 - 1223 moves
# Round 318 - 1311 moves
# Round 319 - 1245 moves
# Round 320 - 1372 moves
# Round 321 - 1262 moves
# Round 322 - 1311 moves
# Round 323 - 1240 moves
# Round 324 - 1308 moves
# Round 325 - 1258 moves
# Round 326 - 1324 moves
# Round 327 - 1277 moves
# Round 328 - 1346 moves
# Round 329 - 1268 moves
# Round 330 - 1318 moves
# Round 331 - 1222 moves
# Round 332 - 1361 moves
# Round 333 - 1262 moves
# Round 334 - 1335 moves
# Round 335 - 1263 moves
# Round 336 - 1335 moves
# Round 337 - 1282 moves
# Round 338 - 1367 moves
# Round 339 - 1313 moves
# Round 340 - 1360 moves
# Round 341 - 1307 moves
# Round 342 - 1380 moves
# Round 343 - 1281 moves
# Round 344 - 1328 moves
# Round 345 - 1253 moves
# Round 346 - 1343 moves
# Round 347 - 1248 moves
# Round 348 - 1344 moves
# Round 349 - 1289 moves
# Round 350 - 1333 moves
# Round 351 - 1255 moves
# Round 352 - 1347 moves
# Round 353 - 1237 moves
# Round 354 - 1296 moves
# Round 355 - 1236 moves
# Round 356 - 1324 moves
# Round 357 - 1237 moves
# Round 358 - 1307 moves
# Round 359 - 1228 moves
# Round 360 - 1287 moves
# Round 361 - 1202 moves
# Round 362 - 1276 moves
# Round 363 - 1239 moves
# Round 364 - 1372 moves
# Round 365 - 1275 moves
# Round 366 - 1351 moves
# Round 367 - 1265 moves
# Round 368 - 1351 moves
# Round 369 - 1218 moves
# Round 370 - 1315 moves
# Round 371 - 1214 moves
# Round 372 - 1298 moves
# Round 373 - 1241 moves
# Round 374 - 1325 moves
# Round 375 - 1227 moves
# Round 376 - 1310 moves
# Round 377 - 1208 moves
# Round 378 - 1312 moves
# Round 379 - 1240 moves
# Round 380 - 1318 moves
# Round 381 - 1235 moves
# Round 382 - 1336 moves
# Round 383 - 1302 moves
# Round 384 - 1357 moves
# Round 385 - 1232 moves
# Round 386 - 1325 moves
# Round 387 - 1233 moves
# Round 388 - 1306 moves
# Round 389 - 1228 moves
# Round 390 - 1283 moves
# Round 391 - 1226 moves
# Round 392 - 1314 moves
# Round 393 - 1235 moves
# Round 394 - 1326 moves
# Round 395 - 1253 moves
# Round 396 - 1338 moves
# Round 397 - 1261 moves
# Round 398 - 1327 moves
# Round 399 - 1247 moves
# Round 400 - 1318 moves
# Round 401 - 1254 moves
# Round 402 - 1307 moves
# Round 403 - 1245 moves
# Round 404 - 1352 moves
# Round 405 - 1244 moves
# Round 406 - 1320 moves
# Round 407 - 1266 moves
# Round 408 - 1330 moves
# Round 409 - 1279 moves
# Round 410 - 1361 moves
# Round 411 - 1299 moves
# Round 412 - 1312 moves
# Round 413 - 1206 moves
# Round 414 - 1301 moves
# Round 415 - 1280 moves
# Round 416 - 1377 moves
# Round 417 - 1306 moves
# Round 418 - 1347 moves
# Round 419 - 1315 moves
# Round 420 - 1324 moves
# Round 421 - 1263 moves
# Round 422 - 1315 moves
# Round 423 - 1228 moves
# Round 424 - 1296 moves
# Round 425 - 1248 moves
# Round 426 - 1306 moves
# Round 427 - 1246 moves
# Round 428 - 1312 moves
# Round 429 - 1230 moves
# Round 430 - 1299 moves
# Round 431 - 1223 moves
# Round 432 - 1296 moves
# Round 433 - 1232 moves
# Round 434 - 1292 moves
# Round 435 - 1232 moves
# Round 436 - 1294 moves
# Round 437 - 1256 moves
# Round 438 - 1360 moves
# Round 439 - 1268 moves
# Round 440 - 1317 moves
# Round 441 - 1225 moves
# Round 442 - 1353 moves
# Round 443 - 1288 moves
# Round 444 - 1348 moves
# Round 445 - 1295 moves
# Round 446 - 1372 moves
# Round 447 - 1288 moves
# Round 448 - 1356 moves
# Round 449 - 1261 moves
# Round 450 - 1319 moves
# Round 451 - 1234 moves
# Round 452 - 1294 moves
# Round 453 - 1242 moves
# Round 454 - 1319 moves
# Round 455 - 1242 moves
# Round 456 - 1329 moves
# Round 457 - 1265 moves
# Round 458 - 1325 moves
# Round 459 - 1275 moves
# Round 460 - 1352 moves
# Round 461 - 1288 moves
# Round 462 - 1376 moves
# Round 463 - 1260 moves
# Round 464 - 1297 moves
# Round 465 - 1280 moves
# Round 466 - 1358 moves
# Round 467 - 1299 moves
# Round 468 - 1375 moves
# Round 469 - 1297 moves
# Round 470 - 1342 moves
# Round 471 - 1279 moves
# Round 472 - 1334 moves
# Round 473 - 1223 moves
# Round 474 - 1304 moves
# Round 475 - 1247 moves
# Round 476 - 1324 moves
# Round 477 - 1243 moves
# Round 478 - 1289 moves
# Round 479 - 1216 moves
# Round 480 - 1264 moves
# Round 481 - 1160 moves
# Round 482 - 1215 moves
# Round 483 - 1163 moves
# Round 484 - 1216 moves
# Round 485 - 1150 moves
# Round 486 - 1165 moves
# Round 487 - 1155 moves
# Round 488 - 1239 moves
# Round 489 - 1190 moves
# Round 490 - 1240 moves
# Round 491 - 1175 moves
# Round 492 - 1249 moves
# Round 493 - 1144 moves
# Round 494 - 1224 moves
# Round 495 - 1171 moves
# Round 496 - 1266 moves
# Round 497 - 1243 moves
